# %% [markdown]
# <a href="https://colab.research.google.com/github/HaSeoHyun/DataScience_Python_Practice/blob/main/XML_to_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
API 데이터 크롤링 - XML to pandas

# %%
url = "http://data4library.kr/api/itemSrch?libCode=127058&startDt=2017-06-01&endDt=2017-06-30&authKey=202131369056477804e4a1b1d7aed549ec135ccac0b9a372a3c6ea23fc6fbf7b5a3f833ed2"
import pandas as pd
#pd.__version__  #colab version 1.3.0 이상부터 지원하는 pd.read_xml()
pd.read_xml(url, xpath = './/doc')  #중요 별 다섯개!!! './/어쩌구'를 매개변수로 분류할 주제를 넣어줘야 제대로 작동한다.
# Out:
#                                              bookname  \
# 0                                        어쩌다 우린 가족일까?
# 1                                  로봇 친구 앤디 :박현경 장편동화
# 2                                                 알사탕
# 3                           그날, 고양이가 내게로 왔다 :김중미 장편소설
# 4                                                   문
# 5                                       아몬드 :손원평 장편소설
# 6                          화가 나는 건 당연해!:화를 슬기롭게 다루는 법
# 7                                            나쁜 말이 불쑥
# 8   (명장면·명대사로 배우는) 스크린 영어회화 :픽사 편 =Screen English ...
# 9                                    흉터와 무늬 :최영미 장편소설
# 10                                               사기열전
# 11                                       재미있는 성품학교. 2
# 12                                              나무 도장
# 13                 왜 그렇게 생각해? :작은 철학자가 만난 10인의 동양 사상가
# 14  샬레스위스 =Chalet Swiss :샬레트래블앤라이프의 여행 전문가 팀이 만든 감...
# 15              스위스 셀프트래블 =Switzerland :2017-2018 최신판
# ...
